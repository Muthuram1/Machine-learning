# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dataset=pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x = dataset.iloc[:,[3,4]].values

# %%
from sklearn.cluster import SpectralClustering
SC =SpectralClustering(n_clusters=2,random_state=0).fit(x)
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 446 with accuracies
# [2.14404505e-15 4.26494485e-06 2.74148737e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 446 instead with accuracy
# 2.3354774075813613e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [1.59037385e-15 4.26494386e-06 2.74148891e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
y_SC=SC.fit_predict(x)
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited at iteration 446 with accuracies
# [2.14404505e-15 4.26494485e-06 2.74148737e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 446 instead with accuracy
# 2.3354774075813613e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:449: UserWarning: Exited postprocessing with accuracies
# [1.59037385e-15 4.26494386e-06 2.74148891e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# C:\Anaconda\envs\aiml\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
supervised=pd.DataFrame(dataset)
supervised['Cluster_group']=y_SC

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 195              0
# 196              0
# 197              0
# 198              1
# 199              0
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],fit_reg=False,legend=True,legend_out=True)
# Out:
# C:\Anaconda\envs\aiml\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
